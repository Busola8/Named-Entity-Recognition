# %% [markdown]
# # NER Project Notebook\nThis notebook explains how to train and run the NER model.

# %%
# Example: run inference\nfrom app.inference import load_model, extract_entities\nnlp = load_model()\nprint(extract_entities('John Doe, email: john@doe.com, Lagos.'))
